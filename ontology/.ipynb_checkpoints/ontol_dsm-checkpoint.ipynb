# %% [markdown]
# # Introduction
#
# This notebook translates the disorders in the [DSM-5](https://dsm.psychiatryonline.org/doi/book/10.1176/appi.books.9780890425596) into the language of the psychiatric neuroimaging literature. The objective is to maximize semantic similarity between the centroid of seed terms from the DSM-5 (i.e., disorder names) and the centroid of a new list of terms for mental functions and dysfunctions. Seed terms are grouped by the headings in Section II of the DSM-5. The work flow is as follows:
#
# 1. Identify the most semantically similar terms to each domain centroid across list lengths.
# 2. Select the word list length that maximizes semantic similarity to the domain centroid.
# 3. Filter domains by document frequency of their assigned terms.
#
# Our vector space model for semantic content is [GloVe](https://github.com/stanfordnlp/GloVe), which was trained on 26,070 psychiatric neuroimaging articles. The parameters for the GloVe model were a minimum word count of 5, window size of 15, and embedding dimension of 100 over 500 iterations.

# %% [markdown]
# # Load the data

# %%
import pandas as pd
from collections import OrderedDict
import sys
sys.path.append("..")
import utilities, ontology

# %%
vsm_version = 190428 # Version of GloVe embeddings
dtm_version = 190325 # Version of document-term matrix

# %% [markdown]
# ## Vector space model

# %%
vsm = pd.read_csv("../data/text/glove_psy_n100_win15_min5_iter500_{}.txt".format(vsm_version), 
                  index_col=0, header=None, sep=" ")
print("Vocab N={}, Embedding N={}".format(vsm.shape[0], vsm.shape[1]))
# Out:
# Vocab N=320502, Embedding N=100

# %% [markdown]
# ## Document-term matrix

# %%
dtm = utilities.load_doc_term_matrix(version=dtm_version, binarize=False)
dtm = dtm.loc[:, (dtm != 0).any(axis=0)]
print("Document N={}, Term N={}".format(dtm.shape[0], dtm.shape[1]))
# Out:
# Document N=18155, Term N=4107

# %%
dtm_bin = utilities.doc_mean_thres(dtm)

# %% [markdown]
# ## DSM-5 seed terms

# %%
seed_df = pd.read_csv("../data/text/seeds_dsm5.csv", index_col=None, header=0)
seed_df.head()
# Out:
#    ORDER                          NAME         DOMAIN  \
# 0      0  Neurodevelopmental Disorders  DEVELOPMENTAL
# 1      0  Neurodevelopmental Disorders  DEVELOPMENTAL
# 2      0  Neurodevelopmental Disorders  DEVELOPMENTAL
# 3      0  Neurodevelopmental Disorders  DEVELOPMENTAL
# 4      0  Neurodevelopmental Disorders  DEVELOPMENTAL
#
#                  CONSTRUCT                                            TOKEN
# 0  INTELLECTUAL_DISABILITY              borderline_intellectual_functioning
# 1  INTELLECTUAL_DISABILITY                       global_developmental_delay
# 2  INTELLECTUAL_DISABILITY              intellectual_developmental_disorder
# 3  INTELLECTUAL_DISABILITY                          intellectual_disability
# 4  INTELLECTUAL_DISABILITY  unspecified_intellectual_developmental_disorder

# %% [markdown]
# ## Lexicon

# %%
lexicon = utilities.load_lexicon(["cogneuro", "dsm", "psychiatry"])
lexicon = sorted(list(set(lexicon).intersection(vsm.index).intersection(dtm.columns)))
len(lexicon)
# Out:
# 2170

# %% [markdown]
# # Generate term lists
#
# ## 1. Identify semantically similar terms

# %%
import numpy as np
np.random.seed(42)
from scipy.spatial.distance import cdist

# %%
doms = list(OrderedDict.fromkeys(seed_df["DOMAIN"]))

# %%
class_tkns = []
for dom in doms:
    class_tkns += set(seed_df.loc[seed_df["DOMAIN"] == dom, "TOKEN"])
unique = [tkn for tkn in class_tkns if class_tkns.count(tkn) == 1]

# %%
list_len = 25
n_terms = range(5, list_len+1)
lists = ontology.load_dsm_lists(lexicon, vsm, seed_df, n_terms=n_terms, verbose=True)
# Out:
# No tokens assigned to PARAPHILIC
# /Users/ehbeam/Documents/Stanford/PhD/Repos/neuro-knowledge-engine/ontology/ontology.py:610: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   seed_centroid = np.mean(vsm.loc[seed_tkns])

# %%
lists.to_csv("lists/lists_dsm.csv", index=None)

# %% [markdown]
# ## 2. Optimize length by similarity to seeds

# %%
from scipy.spatial.distance import cosine

# %%
ops = []
df = pd.DataFrame(index=doms, columns=n_terms)
for dom in doms:
    seed_tkns = seed_df.loc[seed_df["DOMAIN"] == dom, "TOKEN"]
    seed_centroid = np.mean(vsm.loc[seed_tkns])
    for list_len in n_terms:
        len_tkns = lists.loc[lists["DOMAIN"] == dom, "TOKEN"][:list_len]
        len_centroid = np.mean(vsm.loc[len_tkns])
        df.loc[dom, list_len] = 1.0 - cosine(seed_centroid, len_centroid)
    sims = list(df.loc[dom])
    idx = sims.index(max(sims))
    ops.append(np.array(n_terms)[idx])
df["OPTIMAL"] = ops
df.head()
# Out:
# /anaconda3/envs/ontol/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """
#                       5         6         7         8         9        10  \
# DEVELOPMENTAL  0.842878  0.874142  0.876722  0.858471   0.85879  0.860372
# PSYCHOTIC      0.923092  0.912906   0.93035  0.964835  0.964835  0.964835
# BIPOLAR        0.935947  0.935228  0.938526  0.938526  0.938526  0.938526
# DEPRESSIVE     0.878519  0.867078  0.862643  0.868946  0.874244  0.886621
# ANXIETY        0.969206  0.977501  0.987007   0.98318  0.975769   0.99092
#
#                      11        12        13        14  ...        17  \
# DEVELOPMENTAL   0.88926  0.893453  0.900743  0.907104  ...  0.914506
# PSYCHOTIC      0.964835  0.964835  0.964835  0.964835  ...  0.964835
# BIPOLAR        0.938526  0.938526  0.938526  0.938526  ...  0.938526
# DEPRESSIVE     0.871442  0.874232  0.879589  0.884465  ...  0.892689
# ANXIETY         0.99092   0.99092   0.99092   0.99092  ...   0.99092
#
#                      18        19        20        21        22        23  \
# DEVELOPMENTAL  0.914506  0.914506  0.914506  0.914506  0.914506  0.914506
# PSYCHOTIC      0.964835  0.964835  0.964835  0.964835  0.964835  0.964835
# BIPOLAR        0.938526  0.938526  0.938526  0.938526  0.938526  0.938526
# DEPRESSIVE     0.892689  0.892689  0.892689  0.892689  0.892689  0.892689
# ANXIETY         0.99092   0.99092   0.99092   0.99092   0.99092   0.99092
#
#                      24        25 OPTIMAL
# DEVELOPMENTAL  0.914506  0.914506      16
# PSYCHOTIC      0.964835  0.964835       8
# BIPOLAR        0.938526  0.938526       7
# DEPRESSIVE     0.892689  0.892689      15
# ANXIETY         0.99092   0.99092      10
#
# [5 rows x 22 columns]

# %%
columns = ["ORDER", "DOMAIN", "TOKEN", "SOURCE", "DISTANCE"]
new = pd.DataFrame(columns=columns)
for order, dom in enumerate(doms):
    list_len = df.loc[dom, "OPTIMAL"]
    dom_df = lists.loc[lists["DOMAIN"] == dom][:list_len]
    new = new.append(dom_df)

# %% [markdown]
# ## 3. Filter domains by document frequency of terms

# %%
from style import style

# %%
doms = list(OrderedDict.fromkeys(seed_df["DOMAIN"]))
filt_doms = []
for dom in doms: 
    tkns = set(new.loc[new["DOMAIN"] == dom, "TOKEN"])
    freq = sum([1.0 for doc in dtm_bin[tkns].sum(axis=1) if doc > 0]) / float(len(dtm))
    if freq > 0.05:
        print("{:20s} {:6.4f}".format(dom, freq))
        filt_doms.append(dom)
doms = filt_doms
# Out:
# DEVELOPMENTAL        0.2303
# PSYCHOTIC            0.1040
# BIPOLAR              0.1931
# DEPRESSIVE           0.2999
# ANXIETY              0.1362
# OBSESSIVE_COMPULSIVE 0.0619
# TRAUMA_STRESSOR      0.0709
# DISRUPTIVE           0.0635
# SUBSTANCE            0.0882

# %%
new = new.loc[new["DOMAIN"].isin(filt_doms)]
new = new.loc[new["DISTANCE"] > 0]
print("Domains after filtering: N={}".format(len(set(new["DOMAIN"]))))
# Out:
# Domains after filtering: N=9

# %%
doms = style.order["dsm"]

# %%
new["ORDER"] = [doms.index(dom) for dom in new["DOMAIN"]]
new = new.sort_values(["ORDER", "DISTANCE"], ascending=[True, True])
new.head(50)
# Out:
#    ORDER                DOMAIN                            TOKEN   SOURCE  \
# 0      0            DEPRESSIVE        major_depressive_disorder      DSM
# 0      0            DEPRESSIVE                        dysthymia      DSM
# 0      0            DEPRESSIVE              depressive_disorder      DSM
# 0      0            DEPRESSIVE                 major_depression  Lexicon
# 0      0            DEPRESSIVE                              mdd      DSM
# 0      0            DEPRESSIVE                       depressive  Lexicon
# 0      0            DEPRESSIVE                    mood_disorder  Lexicon
# 0      0            DEPRESSIVE               bipolar_depression  Lexicon
# 0      0            DEPRESSIVE                 major_depressive  Lexicon
# 0      0            DEPRESSIVE              generalized_anxiety  Lexicon
# 0      0            DEPRESSIVE                       depression  Lexicon
# 0      0            DEPRESSIVE                       bipolar_ii  Lexicon
# 0      0            DEPRESSIVE         major_depressive_episode  Lexicon
# 0      0            DEPRESSIVE  borderline_personality_disorder  Lexicon
# 0      0            DEPRESSIVE                  mental_disorder  Lexicon
# 0      1               ANXIETY                    social_phobia      DSM
# 0      1               ANXIETY     generalized_anxiety_disorder      DSM
# 0      1               ANXIETY                   panic_disorder      DSM
# 0      1               ANXIETY          social_anxiety_disorder      DSM
# 0      1               ANXIETY                  specific_phobia      DSM
# 0      1               ANXIETY                 anxiety_disorder      DSM
# 0      1               ANXIETY                      agoraphobia      DSM
# 0      1               ANXIETY              generalized_anxiety  Lexicon
# 0      1               ANXIETY                           phobia  Lexicon
# 0      1               ANXIETY      separation_anxiety_disorder      DSM
# 0      2       TRAUMA_STRESSOR    posttraumatic_stress_disorder      DSM
# 0      2       TRAUMA_STRESSOR            acute_stress_disorder      DSM
# 0      2       TRAUMA_STRESSOR           traumarelated_disorder      DSM
# 0      2       TRAUMA_STRESSOR                             ptsd      DSM
# 0      2       TRAUMA_STRESSOR              adjustment_disorder      DSM
# 0      3  OBSESSIVE_COMPULSIVE                 trichotillomania      DSM
# 0      3  OBSESSIVE_COMPULSIVE         body_dysmorphic_disorder      DSM
# 0      3  OBSESSIVE_COMPULSIVE     obsessivecompulsive_disorder      DSM
# 0      3  OBSESSIVE_COMPULSIVE    obsessive_compulsive_disorder      DSM
# 0      3  OBSESSIVE_COMPULSIVE             skinpicking_disorder      DSM
# 0      3  OBSESSIVE_COMPULSIVE            skin_picking_disorder      DSM
# 0      3  OBSESSIVE_COMPULSIVE             excoriation_disorder      DSM
# 0      4            DISRUPTIVE              disruptive_disorder      DSM
# 0      4            DISRUPTIVE                 conduct_disorder      DSM
# 0      4            DISRUPTIVE  intermittent_explosive_disorder      DSM
# 0      4            DISRUPTIVE                      kleptomania      DSM
# 0      4            DISRUPTIVE            psychiatric_diagnosis  Lexicon
# 0      4            DISRUPTIVE         impulse_control_disorder      DSM
# 0      4            DISRUPTIVE               cocaine_dependence  Lexicon
# 0      4            DISRUPTIVE    oppositional_defiant_disorder      DSM
# 0      5             SUBSTANCE              opioid_use_disorder      DSM
# 0      5             SUBSTANCE        substancerelated_disorder      DSM
# 0      5             SUBSTANCE           substance_use_disorder      DSM
# 0      5             SUBSTANCE            cannabis_use_disorder      DSM
# 0      5             SUBSTANCE             cocaine_use_disorder      DSM
#
#    DISTANCE
# 0  0.224319
# 0  0.254927
# 0  0.272039
# 0  0.321286
# 0  0.338441
# 0  0.355606
# 0  0.386951
# 0  0.394994
# 0  0.408686
# 0  0.415482
# 0  0.430989
# 0  0.446217
# 0  0.447464
# 0  0.465521
# 0  0.480151
# 0  0.146308
# 0  0.148786
# 0  0.161855
# 0  0.176759
# 0  0.193711
# 0  0.210436
# 0  0.252374
# 0  0.313419
# 0  0.363378
# 0  0.395745
# 0  0.268614
# 0  0.373865
# 0  0.397502
# 0  0.407933
# 0  0.442189
# 0  0.283919
# 0  0.363679
# 0  0.384053
# 0  0.396622
# 0  0.432549
# 0  0.481429
# 0  0.498848
# 0  0.355635
# 0  0.377977
# 0  0.454252
# 0  0.466572
# 0  0.482570
# 0  0.483826
# 0  0.484020
# 0  0.498019
# 0  0.449433
# 0  0.451212
# 0  0.456084
# 0  0.457031
# 0  0.460637

# %%
df = df.loc[doms]
df.head(len(doms))
# Out:
#                              5         6         7         8         9  \
# DEPRESSIVE            0.878519  0.867078  0.862643  0.868946  0.874244
# ANXIETY               0.969206  0.977501  0.987007   0.98318  0.975769
# TRAUMA_STRESSOR              1         1         1         1         1
# OBSESSIVE_COMPULSIVE  0.895532  0.917471  0.954186  0.954186  0.954186
# DISRUPTIVE            0.898522    0.9303  0.927853  0.943144  0.943144
# SUBSTANCE              0.79108  0.794224  0.794401   0.79101  0.815823
# DEVELOPMENTAL         0.842878  0.874142  0.876722  0.858471   0.85879
# PSYCHOTIC             0.923092  0.912906   0.93035  0.964835  0.964835
# BIPOLAR               0.935947  0.935228  0.938526  0.938526  0.938526
#
#                             10        11        12        13        14  ...  \
# DEPRESSIVE            0.886621  0.871442  0.874232  0.879589  0.884465  ...
# ANXIETY                0.99092   0.99092   0.99092   0.99092   0.99092  ...
# TRAUMA_STRESSOR              1         1         1         1         1  ...
# OBSESSIVE_COMPULSIVE  0.954186  0.954186  0.954186  0.954186  0.954186  ...
# DISRUPTIVE            0.943144  0.943144  0.943144  0.943144  0.943144  ...
# SUBSTANCE             0.837296  0.837296  0.837296  0.837296  0.837296  ...
# DEVELOPMENTAL         0.860372   0.88926  0.893453  0.900743  0.907104  ...
# PSYCHOTIC             0.964835  0.964835  0.964835  0.964835  0.964835  ...
# BIPOLAR               0.938526  0.938526  0.938526  0.938526  0.938526  ...
#
#                             17        18        19        20        21  \
# DEPRESSIVE            0.892689  0.892689  0.892689  0.892689  0.892689
# ANXIETY                0.99092   0.99092   0.99092   0.99092   0.99092
# TRAUMA_STRESSOR              1         1         1         1         1
# OBSESSIVE_COMPULSIVE  0.954186  0.954186  0.954186  0.954186  0.954186
# DISRUPTIVE            0.943144  0.943144  0.943144  0.943144  0.943144
# SUBSTANCE             0.837296  0.837296  0.837296  0.837296  0.837296
# DEVELOPMENTAL         0.914506  0.914506  0.914506  0.914506  0.914506
# PSYCHOTIC             0.964835  0.964835  0.964835  0.964835  0.964835
# BIPOLAR               0.938526  0.938526  0.938526  0.938526  0.938526
#
#                             22        23        24        25 OPTIMAL
# DEPRESSIVE            0.892689  0.892689  0.892689  0.892689      15
# ANXIETY                0.99092   0.99092   0.99092   0.99092      10
# TRAUMA_STRESSOR              1         1         1         1       5
# OBSESSIVE_COMPULSIVE  0.954186  0.954186  0.954186  0.954186       7
# DISRUPTIVE            0.943144  0.943144  0.943144  0.943144       8
# SUBSTANCE             0.837296  0.837296  0.837296  0.837296      10
# DEVELOPMENTAL         0.914506  0.914506  0.914506  0.914506      16
# PSYCHOTIC             0.964835  0.964835  0.964835  0.964835       8
# BIPOLAR               0.938526  0.938526  0.938526  0.938526       7
#
# [9 rows x 22 columns]

# %%
df.to_csv("data/df_dsm_opsim.csv")
new.to_csv("lists/lists_dsm_opsim.csv", index=None)

# %% [markdown]
# # Assess similarity to seeds

# %%
n_iter = 10000

# %% [markdown]
# ### Centroids

# %%
seed_centroid = ontology.compute_centroid(seed_df, doms, vsm)
new_centroid = ontology.compute_centroid(new, doms, vsm)

# %% [markdown]
# ### Bootstrap distribution

# %%
sim_boot = np.zeros((len(doms), n_iter))
for n in range(n_iter):
    sim_boot[:,n] = 1.0 - ontology.compute_sims_sample(new_centroid, seed_centroid, vsm)

# %% [markdown]
# ### Null distribution

# %%
sim_null = np.empty((len(doms), n_iter))
for n in range(n_iter):
    sim_null[:,n] = 1.0 - ontology.compute_sims_shuffle(new_centroid, seed_centroid, vsm)

# %% [markdown]
# ### Observed values

# %%
sim_obs = np.reshape(1.0 - ontology.compute_sims(new, seed_centroid, doms, vsm), (len(doms),1))

# %% [markdown]
# ### Comparison test
#
# Is similarity to DSM seed centroids higher for **new vs. null** models?

# %%
from statsmodels.stats.multitest import multipletests

# %%
alphas = [0.01, 0.001, 0.0001]

# %%
pvals = np.sum(np.less(sim_obs, sim_null), axis=1) / n_iter
fdrs = multipletests(pvals, method="fdr_bh")[1]
ontology.report_significance(fdrs, doms, alphas=alphas)
# Out:
# DEPRESSIVE             p=0.000000 ***
# ANXIETY                p=0.000000 ***
# TRAUMA_STRESSOR        p=0.000000 ***
# OBSESSIVE_COMPULSIVE   p=0.000000 ***
# DISRUPTIVE             p=0.000000 ***
# SUBSTANCE              p=0.000000 ***
# DEVELOPMENTAL          p=0.000000 ***
# PSYCHOTIC              p=0.000000 ***
# BIPOLAR                p=0.000000 ***

# %% [markdown]
# ### Null confidence interval

# %%
interval = 0.95
lower = [sorted(sim_null[i,:])[int(n_iter*(1.0-interval))] for i in range(len(doms))]
upper = [sorted(sim_null[i,:])[int(n_iter*interval)] for i in range(len(doms))]

# %% [markdown]
# ## Plot results
#
# Comparison of new method vs. method of McCoy *et al.* in terms of similarity between the synonyms and RDoC seed terms. Statistics based on bootstrapping and permutation testing.

# %%
import matplotlib.pyplot as plt
from matplotlib import cm, font_manager, rcParams
# %matplotlib inline

# %%
arial = "../style/Arial Unicode.ttf"
prop_md = font_manager.FontProperties(fname=arial, size=16)
prop_lg = font_manager.FontProperties(fname=arial, size=22)
prop_xlg = font_manager.FontProperties(fname=arial, size=25)
rcParams["axes.linewidth"] = 1.5

# %%
dom_names = [dom.replace("_", "-").title() for dom in doms]
palette = style.palettes["dsm"]

# %%
# Set up figure
fig = plt.figure(figsize=(3.5, 4.5))
ax = fig.add_axes([0,0,1,1])

# Null distributions as line plot
plt.plot(range(len(doms)), sim_null.mean(axis=1),
         "gray", linestyle="dashed", linewidth=2)
plt.fill_between(range(len(doms)), lower, y2=upper, 
                 color="gray", alpha=0.2)

# Bootstrap distributions as violin plots
for i, dom in enumerate(doms):
    for data, obs in [(sim_boot, sim_obs)]:
        data = sorted(data[i])
        v = ax.violinplot(data, positions=[i], 
                          showmeans=False, showmedians=False, widths=0.8)
        for pc in v["bodies"]:
            pc.set_facecolor(palette[i])
            pc.set_edgecolor(palette[i])
            pc.set_linewidth(0.5)
            pc.set_alpha(0.6)
        for line in ["cmaxes", "cmins", "cbars"]:
            v[line].set_edgecolor("none")
        plt.plot([i-0.33, i+0.33], [np.mean(obs[i]), np.mean(obs[i])], 
                 c=palette[i], alpha=1, lw=2)

# Set plot parameters
ax.set_xticks(range(len(doms)))
ax.set_xticklabels(dom_names, rotation=60, 
                   ha="right", fontproperties=prop_md)
plt.xticks(fontproperties=prop_md)
plt.yticks(fontproperties=prop_xlg)
ax.yaxis.set_label_coords(-0.35, 0.5)
plt.xlim([-1, len(doms)])
plt.ylim([-0.2, 1])
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.xaxis.set_tick_params(width=1.5)
ax.yaxis.set_tick_params(width=1.5, length=5)

# Export figure
plt.savefig("figures/dsm_seed_sim.png", dpi=250, bbox_inches="tight")
plt.show()

# %% [markdown]
# # Visualize the term lists

# %%
new["SIMILARITY"] = 1.0 - new["DISTANCE"]
new.head()
# Out:
#    ORDER      DOMAIN                      TOKEN   SOURCE  DISTANCE  SIMILARITY
# 0      0  DEPRESSIVE  major_depressive_disorder      DSM  0.224319    0.775681
# 0      0  DEPRESSIVE                  dysthymia      DSM  0.254927    0.745073
# 0      0  DEPRESSIVE        depressive_disorder      DSM  0.272039    0.727961
# 0      0  DEPRESSIVE           major_depression  Lexicon  0.321286    0.678714
# 0      0  DEPRESSIVE                        mdd      DSM  0.338441    0.661559

# %%
ontology.plot_wordclouds("dsm", style.order["dsm"], new, metric="SIMILARITY",
                         palette=palette, height=300, width=260, 
                         min_font_size=0, max_font_size=50,
                         brightness_offset=0.15, darkness_offset=-0.35, n_offsets=25)
# Out:
# DEPRESSIVE
# ANXIETY
# TRAUMA_STRESSOR
# OBSESSIVE_COMPULSIVE
# DISRUPTIVE
# SUBSTANCE
# DEVELOPMENTAL
# PSYCHOTIC
# BIPOLAR

# %% [markdown]
# # Visualize the circuits

# %% [markdown]
# ## Compute PPMI-weighted links

# %%
act_bin = utilities.load_coordinates()
print("Document N={}, Structure N={}".format(act_bin.shape[0], act_bin.shape[1]))
# Out:
# Document N=18155, Structure N=118

# %%
dtm_bin = utilities.load_doc_term_matrix(version=dtm_version, binarize=True)

# %%
scores = utilities.score_lists(new, dtm_bin, label_var="DOMAIN")
print("Document N={}, Structure N={}".format(scores.shape[0], scores.shape[1]))
# Out:
# Document N=18155, Structure N=9

# %%
pmids = act_bin.index.intersection(scores.index)
len(pmids)
# Out:
# 18155

# %%
act_bin = act_bin.loc[pmids]
scores = scores.loc[pmids]

# %%
dom_links = ontology.compute_cooccurrences(act_bin, scores)

# %%
n_iter = 10000
dom_links_null = ontology.compute_cooccurrences_null(act_bin, scores, 
                                                     n_iter=n_iter, verbose=True)
# Out:
# Iteration 0
# Iteration 1000
# Iteration 2000
# Iteration 3000
# Iteration 4000
# Iteration 5000
# Iteration 6000
# Iteration 7000
# Iteration 8000
# Iteration 9000

# %%
p = pd.DataFrame(index=act_bin.columns, columns=scores.columns)
for i, struct in enumerate(act_bin.columns):
    for j, dom in enumerate(scores.columns):
        obs = dom_links.values[i,j]
        null = dom_links_null[i,j,:]
        p.loc[struct, dom] = np.sum(null > obs) / float(n_iter)

# %%
fdr = multipletests(p.values.ravel(), method="fdr_bh")[1]
fdr = pd.DataFrame(fdr.reshape(p.shape), 
                   index=act_bin.columns, columns=scores.columns)

# %%
dom_links_thres = dom_links[fdr < 0.01]
dom_links_thres = dom_links_thres.fillna(0.0)

# %%
dom_links_thres.to_csv("circuits/circuits_dsm.csv")

# %% [markdown]
# ## Map PPMI-weighted links

# %%
atlas = utilities.load_atlas()
path = "figures/circuits/dsm"
cmaps = style.colormaps["dsm"]
vmaxs = [round(v, 2) for v in dom_links_thres.max()]
for plane, verbose in zip(["z", "x", "y"], [True, False, False]):
    utilities.map_plane(dom_links_thres, atlas, path, suffix="_"+plane, 
                        cmaps=cmaps, plane=plane, cbar=True, vmin=0.0, vmaxs=vmaxs,
                        verbose=verbose, print_fig=verbose)
# Out:
# /anaconda3/envs/ontol/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# DEPRESSIVE           Min: 0.0000  Mean: 0.0020  Max: 0.0666
# ANXIETY              Min: 0.0000  Mean: 0.0147  Max: 0.3221
# TRAUMA_STRESSOR      Min: 0.0000  Mean: 0.0199  Max: 0.3912
# OBSESSIVE_COMPULSIVE Min: 0.0000  Mean: 0.0073  Max: 0.2019
# DISRUPTIVE           Min: 0.0000  Mean: 0.0145  Max: 0.3482
# SUBSTANCE            Min: 0.0000  Mean: 0.0066  Max: 0.2963
# DEVELOPMENTAL        Min: 0.0000  Mean: 0.0259  Max: 0.1757
# PSYCHOTIC            Min: 0.0000  Mean: 0.0065  Max: 0.0910
# BIPOLAR              Min: 0.0000  Mean: 0.0036  Max: 0.0990
