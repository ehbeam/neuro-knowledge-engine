# %% [markdown]
# # Introduction
#
# This notebook will relate the parcellation of voxels into resting state networks with their parcellations based on the data-driven, RDoC, and DSM frameworks. The resting state atlas is the 7-network solution published by [Yeo *et al.* (2011)](https://www.physiology.org/doi/full/10.1152/jn.00338.2011) and distributed by [Freesurfer](https://surfer.nmr.mgh.harvard.edu/fswiki/CorticalParcellation_Yeo2011).

# %%
import pandas as pd
import numpy as np
np.random.seed(42)
from nilearn import image, plotting

import sys
sys.path.append("..")
from utilities import *

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load resting state networks

# %%
rs_dir = "Yeo_JNeurophysiol11_MNI152"
rs_file = "{}/Yeo2011_7Networks_MNI152_FreeSurferConformed1mm_LiberalMask.nii.gz".format(rs_dir)

# %% [markdown]
# ## Visualize the networks

# %%
cmap_df = pd.read_fwf("{}/Yeo2011_7Networks_ColorLUT.txt".format(rs_dir), index_col=0)
cmap_rgb = cmap_df.values[:,1:4] / 255.0
cmap_col = [(1,1,1)]*8 + [tuple(cmap_rgb[i,:]) for i in range(cmap_rgb.shape[0])]
cmap = make_cmap(cmap_col, n_colors=15)

# %%
display = plotting.plot_stat_map(rs_file,
                                 cmap=cmap, alpha=0.5, 
                                 symmetric_cbar=True, colorbar=False,
                                 annotate=True, draw_cross=False)
display.savefig("figures/rs_xyz.png", dpi=250)
plotting.show()
# Out:
# /Users/ehbeam/anaconda/envs/rdoc/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Extract one matrix per network

# %%
atlas = load_atlas()
atlas.shape
# Out:
# (182, 218, 182)

# %%
rs_img = image.load_img(rs_file)
rs_mat = image.resample_to_img(rs_img, atlas).get_data()[:,:,:,0]
rs_mat.shape
# Out:
# (182, 218, 182)

# %%
rs_mats = {}
for i in range(1,8):
    mat_i = rs_mat.copy()
    mat_i[mat_i != i] = 0.0
    mat_i[mat_i == i] = 1.0
    rs_mats[i] = mat_i

# %%
rs_vecs = np.empty((7, len(rs_mats[1].ravel())))
for i in range(7):
    rs_vecs[i,:] = rs_mats[i+1].ravel()

# %%
cmaps = [make_cmap([tuple(cmap_rgb[i])]*2, n_colors=2) for i in range(7)]

# %%
for i in range(1,8):
    print(i)
    plotting.plot_stat_map(image.new_img_like(atlas, rs_mats[i]), 
                           threshold=0.0, vmax=2.0,
                           cmap=cmaps[i-1], alpha=0.5, 
                           symmetric_cbar=True, colorbar=False,
                           annotate=False, draw_cross=False)
    plotting.show()
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# # Load our brain circuits

# %%
frameworks = ["data-driven", "rdoc", "dsm"]

# %%
def load_circuit_data(framework, level="domain"):
    circuit_file = "../ontology/circuits/circuits_{}_{}.csv".format(level, framework)
    circuits = pd.read_csv(circuit_file, index_col=0, header=0)
    return circuits

# %%
def extract_circuit_mats(framework, level="domain"):
    circuits = load_circuit_data(framework, level=level)
    framework_mats = {}
    mat = image.copy_img(atlas).get_data()
    for circuit, values in circuits.iteritems():
        circuit_mat = mat.copy()
        for i, value in enumerate(values):
            circuit_mat[circuit_mat == i+1] = value
        framework_mats[circuit] = circuit_mat
    return framework_mats

# %%
fw_mats = {fw: extract_circuit_mats(fw) for fw in frameworks}

# %%
plotting.plot_stat_map(image.new_img_like(atlas, fw_mats["kmeans"]["VISION"]), 
                       threshold=0.0, vmax=2.0,
                       cmap="Greens", alpha=0.5, 
                       symmetric_cbar=True, colorbar=False,
                       annotate=False, draw_cross=False)
plotting.show()

# %% [markdown]
# # Relate circuits to resting state networks
#
# ## Vectorize framework data

# %%
from scipy.spatial.distance import cdist

# %%
circuits = {fw: list(load_circuit_data(fw).columns) for fw in frameworks}

# %%
fw_vecs = {}
for fw in frameworks:
    vecs = np.empty((len(circuits[fw]), len(fw_mats[fw][circuits[fw][0]].ravel())))
    for i, circuit in enumerate(circuits[fw]):
        vecs[i,:] = fw_mats[fw][circuit].ravel()
    fw_vecs[fw] = vecs

# %% [markdown]
# ## Filter out voxels that are zero across all images

# %%
voxel_sums = np.sum(rs_vecs, axis=0)
for fw in frameworks:
    voxel_sums += np.sum(fw_vecs[fw], axis=0)
voxel_filter = voxel_sums > 0

# %%
rs_vecs.shape
# Out:
# (7, 7221032)

# %%
rs_vecs = rs_vecs[:,voxel_filter]
rs_vecs.shape
# Out:
# (7, 1468757)

# %%
for fw in frameworks:
    fw_vecs[fw] = fw_vecs[fw][:,voxel_filter]

# %% [markdown]
# ## Compute observed values

# %%
def compute_similarities(framework):
    return 1.0 - cdist(fw_vecs[framework], rs_vecs, metric="cosine")

# %%
sims = {fw: pd.DataFrame(compute_similarities(fw), index=circuits[fw], columns=range(1,8)) for fw in frameworks}

# %%
sims["data-driven"]
# Out:
#                      1         2         3         4         5         6  \
# EMOTION       0.021414  0.000000  0.000049  0.000000  0.184536  0.000000
# ANTICIPATION  0.000000  0.000000  0.000000  0.000000  0.106619  0.000000
# COGNITION     0.004540  0.033275  0.000000  0.226195  0.222850  0.263690
# VISION        0.470717  0.001501  0.178823  0.029037  0.000010  0.062002
# MANIPULATION  0.039052  0.403145  0.298183  0.183841  0.000000  0.263192
# MEANING       0.038713  0.000216  0.032023  0.000000  0.299237  0.028668
# LANGUAGE      0.000000  0.318753  0.000000  0.123394  0.122756  0.012375
#
#                      7
# EMOTION       0.006749
# ANTICIPATION  0.009381
# COGNITION     0.325926
# VISION        0.078327
# MANIPULATION  0.204961
# MEANING       0.182877
# LANGUAGE      0.131055

# %%
sims["rdoc"]
# Out:
#                              1         2         3         4         5  \
# NEGATIVE_VALENCE      0.016592  0.031520  0.004567  0.087275  0.462898
# POSITIVE_VALENCE      0.000225  0.033294  0.000000  0.146935  0.223616
# COGNITIVE_SYSTEMS     0.311803  0.141410  0.395459  0.109544  0.000000
# SOCIAL_PROCESSES      0.138250  0.033400  0.098429  0.027468  0.455009
# AROUSAL_REGULATION    0.056392  0.042032  0.007114  0.031446  0.172115
# SENSORIMOTOR_SYSTEMS  0.012971  0.469757  0.205628  0.174697  0.000008
#
#                              6         7
# NEGATIVE_VALENCE      0.113432  0.175305
# POSITIVE_VALENCE      0.116926  0.159402
# COGNITIVE_SYSTEMS     0.288754  0.266409
# SOCIAL_PROCESSES      0.054170  0.255204
# AROUSAL_REGULATION    0.021451  0.048030
# SENSORIMOTOR_SYSTEMS  0.098229  0.062560

# %%
sims["dsm"]
# Out:
#                              1         2         3         4         5  \
# DEVELOPMENTAL         0.356344  0.127666  0.302257  0.103642  0.020466
# PSYCHOTIC             0.000000  0.000000  0.004325  0.037547  0.000000
# BIPOLAR               0.000047  0.000000  0.000000  0.032785  0.139649
# DEPRESSIVE            0.000551  0.013153  0.000021  0.078282  0.377271
# ANXIETY               0.001080  0.016832  0.000035  0.047352  0.301629
# OBSESSIVE_COMPULSIVE  0.000000  0.037902  0.000000  0.026933  0.040251
# TRAUMA_STRESSOR       0.046371  0.012069  0.003409  0.031749  0.208572
# COGNITIVE             0.073199  0.140184  0.292397  0.088368  0.000010
#
#                              6         7
# DEVELOPMENTAL         0.147916  0.224560
# PSYCHOTIC             0.066379  0.066443
# BIPOLAR               0.184184  0.109799
# DEPRESSIVE            0.168441  0.231137
# ANXIETY               0.010326  0.069098
# OBSESSIVE_COMPULSIVE  0.006454  0.017950
# TRAUMA_STRESSOR       0.003322  0.026246
# COGNITIVE             0.189146  0.159518

# %% [markdown]
# ## Compute null distributions

# %%
n_iter = 10000

# %%
def compute_similarities_null(framework, n_iter=100):
    sim_null = np.empty((len(circuits[framework]), 7, n_iter))
    n_voxels = rs_vecs.shape[1]
    for n in range(n_iter):
        null = np.random.choice(range(n_voxels), size=n_voxels, replace=False)
        sim_null[:,:,n] = 1.0 - cdist(fw_vecs[framework], rs_vecs[:,null], metric="cosine")
        if n % (float(n_iter) / 10.0) == 0:
            print("\tIteration {}".format(n))
    return sim_null

# %%
fw_sim_null = {}
for framework in frameworks:
    print("Computing null for {}".format(framework))
    fw_sim_null[framework] = compute_similarities_null(framework, n_iter=n_iter)
# Out:
# Computing null for kmeans
# 	Iteration 0
# 	Iteration 1000
# 	Iteration 2000
# 	Iteration 3000
# 	Iteration 4000
# 	Iteration 5000
# 	Iteration 6000
# 	Iteration 7000
# 	Iteration 8000
# 	Iteration 9000
# Computing null for rdoc
# 	Iteration 0
# 	Iteration 1000
# 	Iteration 2000
# 	Iteration 3000
# 	Iteration 4000
# 	Iteration 5000
# 	Iteration 6000
# 	Iteration 7000
# 	Iteration 8000
# 	Iteration 9000
# Computing null for dsm
# 	Iteration 0
# 	Iteration 1000
# 	Iteration 2000
# 	Iteration 3000
# 	Iteration 4000
# 	Iteration 5000
# 	Iteration 6000
# 	Iteration 7000
# 	Iteration 8000
# 	Iteration 9000

# %% [markdown]
# ## Perform comparison tests

# %%
from statsmodels.stats import multitest

# %%
def compute_stats(framework):
    
    obs = sims[framework]
    
    p = pd.DataFrame(0.0, index=circuits[framework], columns=range(1,8))
    for i, dom in enumerate(circuits[framework]):  
        for j in range(7):
            dom_null = fw_sim_null[framework][i,j,:]
            p.loc[dom,j+1] = np.sum(dom_null > float(obs.loc[dom,j+1])) / float(n_iter)
    
    p_cor = multitest.multipletests(p.values.ravel(), method="fdr_bh")[1]
    p_cor = pd.DataFrame(p_cor.reshape((len(circuits[framework]), 7)), 
                                       index=circuits[framework], columns=range(1,8))
    
    stars = pd.DataFrame("", index=circuits[framework], columns=range(1,8))
    for dom in circuits[framework]:
        for j in range(1,8):
            for star, alpha in zip(["*", "**", "***"], [0.05, 0.01, 0.001]):
                if p_cor.loc[dom, j] < alpha:
                    stars.loc[dom, j] = star
    
    return {"OBSERVED": obs, "P": p, "P_COR": p_cor, "STARS": stars}

# %%
stats = {fw: compute_stats(fw) for fw in frameworks}

# %%
stats["data-driven"]["STARS"]
# Out:
#                 1    2    3    4    5    6    7
# EMOTION                           ***
# ANTICIPATION                      ***
# COGNITION                    ***  ***  ***  ***
# VISION        ***       ***
# MANIPULATION       ***  ***  ***       ***  ***
# MEANING                           ***       ***
# LANGUAGE           ***       ***  ***       ***

# %%
stats["rdoc"]["STARS"]
# Out:
#                         1    2    3    4    5    6    7
# NEGATIVE_VALENCE                          ***
# POSITIVE_VALENCE                     ***  ***
# COGNITIVE_SYSTEMS     ***       ***            ***  ***
# SOCIAL_PROCESSES       **                 ***       ***
# AROUSAL_REGULATION                        ***
# SENSORIMOTOR_SYSTEMS       ***  ***  ***

# %%
stats["dsm"]["STARS"]
# Out:
#                         1 2    3    4    5    6    7
# DEVELOPMENTAL         ***    ***                 ***
# PSYCHOTIC                         ***       ***  ***
# BIPOLAR                                ***  ***  ***
# DEPRESSIVE                             ***  ***  ***
# ANXIETY                                ***
# OBSESSIVE_COMPULSIVE
# TRAUMA_STRESSOR                        ***
# COGNITIVE                    ***

# %% [markdown]
# # Export results

# %%
for framework in frameworks:
    for stat in ["OBSERVED", "P", "P_COR", "STARS"]:
        df = stats[framework][stat]
        df.to_csv("data/{}_{}_{}iter.csv".format(framework, stat.lower(), n_iter))

# %% [markdown]
# # Print results for figure

# %%
def print_results(fw, scalar=40.0):
    df = stats[fw]["OBSERVED"].copy()
    df = df[stats[fw]["P_COR"] < 0.001]
    df = df * scalar
    df = df.fillna("")
    return df

# %%
print_results("data-driven")
# Out:
#                     1        2        3        4        5        6        7
# EMOTION                                           7.38145
# ANTICIPATION                                      4.26477
# COGNITION                                9.04781  8.91401  10.5476   13.037
# VISION        18.8287           7.15293
# MANIPULATION           16.1258  11.9273  7.35362           10.5277  8.19845
# MEANING                                           11.9695            7.3151
# LANGUAGE               12.7501           4.93577  4.91023            5.2422

# %%
print_results("rdoc")
# Out:
#                             1        2        3        4        5        6  \
# NEGATIVE_VALENCE                                          18.5159
# POSITIVE_VALENCE                                 5.87739  8.94464
# COGNITIVE_SYSTEMS     12.4721           15.8184                    11.5502
# SOCIAL_PROCESSES                                          18.2004
# AROUSAL_REGULATION                                        6.88459
# SENSORIMOTOR_SYSTEMS           18.7903  8.22514  6.98788
#
#                             7
# NEGATIVE_VALENCE
# POSITIVE_VALENCE
# COGNITIVE_SYSTEMS     10.6564
# SOCIAL_PROCESSES      10.2082
# AROUSAL_REGULATION
# SENSORIMOTOR_SYSTEMS

# %%
print_results("dsm")
# Out:
#                             1 2        3        4        5        6        7
# DEVELOPMENTAL         14.2538    12.0903                             8.98241
# PSYCHOTIC                                 1.50187           2.65515  2.65771
# BIPOLAR                                            5.58596  7.36737  4.39196
# DEPRESSIVE                                         15.0908  6.73762  9.24549
# ANXIETY                                            12.0652
# OBSESSIVE_COMPULSIVE
# TRAUMA_STRESSOR                                    8.34288
# COGNITIVE                        11.6959
